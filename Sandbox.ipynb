# %%
# !pip install python-dotenv espn-api pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached espn_api-0.45.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached espn_api-0.45.1-py3-none-any.whl (67 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
# ...
#   WARNING: The script dotenv.exe is installed in 'C:\Users\JakobWalden\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# ...

# %%
import os
from dotenv import load_dotenv, find_dotenv
from espn_api.football import League
import pandas as pd

# %%
load_dotenv(find_dotenv(), override=True)

league = League(
    league_id=int(os.getenv("LEAGUE_ID")),
    year=int(os.getenv("YEAR")),
    espn_s2=os.getenv("ESPN_S2"),
    swid=os.getenv("SWID"),
)

# %%
for t in league.teams:
    print(t.team_id, t.team_name)
# Out:
# 1 3rd and 6 inches
# 2 CMC My D
# 3 Team  Dirty Sanchez
# 4 Team Nestor
# 5 Ms. Billy’s
# 7  Njigbas on Welfare
# 8 Team Conndawg69
# 9 Rub My Chubb
# 10 Hey Scott Are You Awake
# 11 Team Olmsted
# 12 Team Pidcock
# 13 Green Bowl Packers

# %%
my_team = next(t for t in league.teams if t.team_id == 10)

pd.DataFrame([{
    "Name": p.name,
    "Pos": p.position,
    "NFL": getattr(p, "proTeam", ""),
    "Proj": p.projected_avg_points,
    "Owned%": p.percent_owned,
    "Started%": p.percent_started
} for p in my_team.roster])
# Out:
#                  Name   Pos  NFL   Proj  Owned%  Started%
# 0          Puka Nacua    WR  LAR  14.47   99.91     99.12
# 1         Josh Jacobs    RB   GB  15.42   99.87     97.43
# 2      Terry McLaurin    WR  WSH  12.05   99.17     84.87
# 3          Joe Burrow    QB  CIN  19.45   99.84     93.74
# 4         Sam LaPorta    TE  DET   9.08   99.47     93.99
# 5    David Montgomery    RB  DET  11.49   95.62     55.68
# 6      Matthew Golden    WR   GB   9.96   91.13     19.16
# 7        Stefon Diggs    WR   NE   9.58   89.84     14.01
# 8        Keenan Allen    WR  LAC   8.78   76.13      4.48
# 9        Tucker Kraft    TE   GB   7.55   84.75     36.63
# 10      Braelon Allen    RB  NYJ   5.03   43.35      0.54
# 11  Luther Burden III    WR  CHI   4.40   17.86      0.19
# 12    Harrison Butker     K   KC   7.95   80.56     74.51
# 13      Seahawks D/ST  D/ST  SEA   7.08   78.44     68.19
# 14       Adam Thielen    WR  MIN   4.97   43.34      2.88
